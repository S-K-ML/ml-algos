# %% [markdown]
# # ML algorithms tests demo

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.abspath(""), os.pardir)))

# %%
from tests.regression import testLinearRegression
from tests.classification import (
    testBinClassLogisticRegression,
    testPrimalFormBinClassifiers,
    testAdjointFormBinClassifiers,
    testDualFormBinClassifiers,
    testMulClassification
)
from tests.clustering import testKmeansClustering
from tests.dimensionality_reduction import testPCA

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Linear regression with L2, L1 and L infinity objectives

# %%
testLinearRegression()
# Out:
# Linear regression L2 objective pre optimization: 0.09782986404664155
# Linear regression L2 objective post optimization: 0.01849738170739237
# Synthetic data experiments train set losses:
# Synthetic data experiments test set losses:

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Binary classification

# %% [markdown]
# #### Logistic regression

# %%
testBinClassLogisticRegression()
# Out:
# Logistic regression model accuracy: 0.95
# Logistic regression objective pre optimization: 72.29840750819727
# Logistic regression objective post optimization: 5.589937066134235
# Synthetic data experiments train set accuracies:
# Synthetic data experiments test set accuracies:

# %% [markdown]
# #### Binomial deviance loss + L2 regularization, hinge loss + L2 regularization primal form

# %%
testPrimalFormBinClassifiers()
# Out:
# Primal form:
#
# Data model 1:
#
# Binomial deviance loss + L2 reg model:
# Train set accuracy: 1.0
#
# Hinge loss + L2 reg model:
# Train set accuracy: 0.98
#
# Data model 2:
#
# Binomial deviance loss + L2 reg model:
# Train set accuracy: 0.54
#
# Hinge loss + L2 reg model:
# Train set accuracy: 0.55
#
# Data model 3:
#
# Binomial deviance loss + L2 reg model:
# Train set accuracy: 0.87
#
# Hinge loss + L2 reg model:
# Train set accuracy: 0.87
#
# Synthetic data experiments train set accuracies:
# Synthetic data experiments test set accuracies:

# %% [markdown]
# #### Binomial deviance loss + L2 regularization, hinge loss + L2 regularization adjoint form

# %%
testAdjointFormBinClassifiers()
# Out:
# Data model 1:
#
# Linear kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 1.0
#
# Adjoint Hinge loss + L2 reg model:
# Train set accuracy: 0.98
#
# Poly deg 2 kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 0.98
#
# Adjoint Hinge loss + L2 reg model:
# Train set accuracy: 0.98
#
# Poly deg 3 kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 1.0
#
# Adjoint Hinge loss + L2 reg model:
# Train set accuracy: 0.98
#
# Gauss width 0.5 kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 0.99
#
# Adjoint Hinge loss + L2 reg model:
# Train set accuracy: 0.98
#
# Data model 2:
#
# Linear kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 0.54
#
# Adjoint Hinge loss + L2 reg model:
# Train set accuracy: 0.55
#
# Poly deg 2 kernel:
#
# Adjoint Binomial deviance loss + L2 reg model :
# Train set accuracy: 1.0
#
# ...

# %% [markdown]
# #### SVM dual form

# %%
testDualFormBinClassifiers()
# Out:
# Dual form:
#
# Data model 1:
#
# Linear kernel:
# Train set accuracy: 0.98
#
# Poly deg 2 kernel:
# Train set accuracy: 0.98
#
# Poly deg 3 kernel:
# Train set accuracy: 0.98
#
# Gauss width 0.5 kernel:
# Train set accuracy: 0.98
#
# Data model 2:
#
# Linear kernel:
# Train set accuracy: 0.55
#
# Poly deg 2 kernel:
# Train set accuracy: 1.0
#
# Poly deg 3 kernel:
# Train set accuracy: 1.0
#
# Gauss width 0.5 kernel:
# Train set accuracy: 1.0
#
# Data model 3:
#
# Linear kernel:
# Train set accuracy: 0.87
#
# Poly deg 2 kernel:
# Train set accuracy: 0.87
#
# Poly deg 3 kernel:
# Train set accuracy: 1.0
#
# Gauss width 0.5 kernel:
# Train set accuracy: 1.0

# %% [markdown]
# ### Multiclass classification with multinomial deviance loss

# %%
testMulClassification()
# Out:
# Generative model 1:
# Accuracy: 0.9
#
# Generative model 2:
# Accuracy: 0.91
#
#
# Synthetic data experiments train set accuracies:
# Synthetic data experiments test set accuracies:

# %% [markdown]
# ## Dimensionality Reduction

# %% [markdown]
# ### Principal component analysis (PCA)

# %%
testPCA()
# Out:
# Synthetic data experiments train set accuracies:
# Synthetic data experiments test set accuracies:

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### K-means

# %%
testKmeansClustering()
# Out:
# Generative model 1:
#
# Original clusters:
# 4-means clusters:
# Objective value: 1.0058155732062932
#
# 3-means clusters:
# Objective value: 1.1302164774054566
#
# 2-means clusters:
# Objective value: 1.6527657758961218
#
# Generative model 2:
#
# Original clusters:
# 4-means clusters:
# Objective value: 0.8839907522945661
#
# 3-means clusters:
# Objective value: 1.4704729163821333
#
# 2-means clusters:
# Objective value: 2.4829827694933373
#
#
# K selection:
